# %% [markdown]
# * 통신 및 파싱에 사용할 패키지를 가져옵니다. requests와 bs4의 BeautifulSoup

# %% [markdown]
# * 수집할 URL을 저장합니다.

# %% [markdown]
# * requests.get(url)명령을 이용하여 통신한 후 결과를 response 변수에 저장합니다.

# %% [markdown]
# * response 내용을 출력해봅니다.

# %% [markdown]
# * BeautifulSoup를 이용하여 response내용을 html구조로 파싱합니다.

# %% [markdown]
# * 수집한 결과물을 저장할 list 변수를 만들어줍니다.

# %%
title_list =[]

# %% [markdown]
# * 수집할 대상이 되는 글목록을 가져와서 저장합니다.(a태그 중 class가 news_titl인 부분)

# %% [markdown]
# * 반복문을 이용하여 title부분(.text)과 url부분(["href"])을 추출한 후 데이터 순서 번호와 함께 결과리스트에 추가해주세요. 순서번호를 함께 저장하기 위해서 반복문에 enumerate를 활용해보세요.

# %% [markdown]
# * 수고하셨습니다.
